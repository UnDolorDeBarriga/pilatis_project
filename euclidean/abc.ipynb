# %%
from docplex.mp.model import Model
import numpy as np
import pandas as pd
import math as m
import matplotlib.pyplot as plt
import os


# Functions
def euclidean_distance(x1, y1, x2, y2):
    """
    Calculate the Euclidean distance between two points
    Args:
        x1 (int): x coordinate of the first point
        y1 (int): y coordinate of the first point
        x2 (int): x coordinate of the second point
        y2 (int): y coordinate of the second point

    Return:
        int: The Euclidean distance between the two points
    """
    return m.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)


bounding_corridor_size_X = 3
bounding_corridor_size_Y = 3

script_dir = os.getcwd()

wh_cordinates_f = pd.read_csv(os.path.join(script_dir, "..\\data\\wh_coords_OP.csv"))
orders_f = pd.read_csv(os.path.join(script_dir, "..\\data\\orders.csv"))


# Parameters
X = wh_cordinates_f["x"].values
Y = wh_cordinates_f["y"].values

orders = []
for i in range(len(orders_f)):
    k = []
    for j in orders_f.iloc[i]:
        if pd.notna(j):
            k.append(int(j))

    orders.append(k)

s = 1  # Size of a storage unit (in meters)
v = 1  # Speed of the drone
M = len(X)  # Number of storage units
N = len(orders)  # Number of orders
(x_o, y_o) = (0, 0)  # Origin coordinates
d = [0] * N  # Total distance of each order

# total size of the warehouse
x_w, y_w = (
    max(X) * s + bounding_corridor_size_X * 2,
    max(Y) * s + bounding_corridor_size_Y * 2,
)

# Model
mdl = Model(name="Euclidean basquet allocation")

basket_position = mdl.integer_var_list(2, name="basket_position")

for i, order in enumerate(orders):
    for item in order:
        d[i] += 2 * euclidean_distance(
            basket_position[0], basket_position[1], X[item], Y[item]
        )

# Constraints
mdl.add_constraint(basket_position[0] >= 0)
mdl.add_constraint(basket_position[0] <= x_w)
mdl.add_constraint(basket_position[1] >= 0)
mdl.add_constraint(basket_position[1] <= y_w)
mdl.add_constraint(
    basket_position[0] != X[i] and basket_position[1] != Y[i] for i in range(M)
)

# Objective function
mdl.minimize(mdl.sum(d[i] for i in range(N)))
# Out:
# ---------------------------------------------------------------------------
# DOcplexException                          Traceback (most recent call last)
# Cell In[6], line 76
#      74 mdl.add_constraint(basket_position[1] >= 0)
#      75 mdl.add_constraint(basket_position[1] <= y_w)
# ---> 76 mdl.add_constraint(
#      77     basket_position[0] != X[i] and basket_position[1] != Y[i] for i in range(M)
#      78 )
#      80 # Objective function
#      81 mdl.minimize(mdl.sum(d[i] for i in range(N)))
#
# File c:\Users\posky\Documents\Universita\Pilati\my_env\lib\site-packages\docplex\mp\model.py:4123, in Model.add_constraint(self, ct, ctname)
#    4108 def add_constraint(self, ct, ctname=None):
#    4109     """ Adds a new linear constraint to the model.
#    4110
#    4111     Args:
#    (...)
#    4121         :func:`add_constraint_`
#    4122     """
# -> 4123     ct = self._add_constraint_internal(ct, ctname)
#    4124     return ct
#
# File c:\Users\posky\Documents\Universita\Pilati\my_env\lib\site-packages\docplex\mp\model.py:3623, in Model._add_constraint_internal(self, ct, ctname)
#    3620     return self._post_constraint(ct1)
#    3622 check_trivial = self._check_trivial_constraints()
# -> 3623 if self._prepare_constraint(ct, used_ct_name, check_for_trivial_ct=check_trivial):
#    3624     self._post_constraint(ct)
#    3625     return ct
#
# File c:\Users\posky\Documents\Universita\Pilati\my_env\lib\site-packages\docplex\mp\model.py:3589, in Model._prepare_constraint(self, ct, ctname, check_for_trivial_ct, arg_checker)
#    3586     self.fatal(msg)
#    3588 else:
# -> 3589     checker.typecheck_ct_to_add(ct, self, 'add_constraint')
#    3590     # -- watch for trivial cts e.g. linexpr(0) <= linexpr(1)
#    3591     if check_for_trivial_ct and ct.is_trivial():
#
# File c:\Users\posky\Documents\Universita\Pilati\my_env\lib\site-packages\docplex\mp\tck.py:355, in StandardTypeChecker.typecheck_ct_to_add(self, ct, mdl, caller)
#     353 def typecheck_ct_to_add(self, ct, mdl, caller):
#     354     if not isinstance(ct, AbstractConstraint):
# --> 355         self.fatal("Expecting constraint, got: {0!r} with type: {1!s}", ct, type(ct))
#     356     self.typecheck_in_model(mdl, ct, caller)
#
# File c:\Users\posky\Documents\Universita\Pilati\my_env\lib\site-packages\docplex\mp\tck.py:256, in DOcplexLoggerTypeChecker.fatal(self, msg, *args)
#     255 def fatal(self, msg, *args):
# --> 256     self._logger.fatal(msg, args)
#
# File c:\Users\posky\Documents\Universita\Pilati\my_env\lib\site-packages\docplex\mp\error_handler.py:210, in AbstractErrorHandler.fatal(self, msg, args)
#     208 resolved_message = resolve_pattern(msg, args)
#     209 docplex_error_stop_here()
# --> 210 raise DOcplexException(resolved_message)
#
# DOcplexException: Expecting constraint, got: <generator object <genexpr> at 0x000001EF3DE5C2E0> with type: <class 'generator'>
